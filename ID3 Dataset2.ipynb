# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
hotel_data=pd.read_csv("booking data.csv")

# %%
hotel_data.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
hotel_data.shape
# Out:
# (36275, 19)

# %%
hotel_data.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
hotel_data.nunique()
# Out:
# Booking_ID                              36275
# no_of_adults                                5
# no_of_children                              6
# no_of_weekend_nights                        8
# no_of_week_nights                          18
# type_of_meal_plan                           4
# required_car_parking_space                  2
# room_type_reserved                          7
# lead_time                                 352
# arrival_year                                2
# arrival_month                              12
# arrival_date                               31
# market_segment_type                         5
# repeated_guest                              2
# no_of_previous_cancellations                9
# no_of_previous_bookings_not_canceled       59
# avg_price_per_room                       3930
# no_of_special_requests                      6
# booking_status                              2
# dtype: int64

# %%
hotel_data.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
hotel_data["required_car_parking_space"].value_counts()
# Out:
# 0    35151
# 1     1124
# Name: required_car_parking_space, dtype: int64

# %%
hotel_data["type_of_meal_plan"].value_counts()
# Out:
# Meal Plan 1     27835
# Not Selected     5130
# Meal Plan 2      3305
# Meal Plan 3         5
# Name: type_of_meal_plan, dtype: int64

# %%
hotel_data["repeated_guest"].value_counts()
# Out:
# 0    35345
# 1      930
# Name: repeated_guest, dtype: int64

# %%
hotel_data.dtypes
# Out:
# Booking_ID                               object
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# room_type_reserved                       object
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                      object
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %%
hotel_data["market_segment_type"].value_counts()
# Out:
# Online           23214
# Offline          10528
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: market_segment_type, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
sns.countplot('booking_status', data=hotel_data)
# Out:
# <AxesSubplot:xlabel='booking_status', ylabel='count'>

# %%
hotel_data.duplicated().sum()
# Out:
# 0

# %%
corr_matrix=hotel_data.corr()
corr_matrix
# Out:
#                                       no_of_adults  no_of_children  \
# no_of_adults                              1.000000       -0.019787
# no_of_children                           -0.019787        1.000000
# no_of_weekend_nights                      0.103316        0.029478
# no_of_week_nights                         0.105622        0.024398
# required_car_parking_space                0.011429        0.034244
# lead_time                                 0.097287       -0.047091
# arrival_year                              0.076719        0.045983
# arrival_month                             0.021841       -0.003076
# arrival_date                              0.026338        0.025482
# repeated_guest                           -0.192277       -0.036348
# no_of_previous_cancellations             -0.047426       -0.016390
# no_of_previous_bookings_not_canceled     -0.119166       -0.021189
# avg_price_per_room                        0.296886        0.337728
# ...

# %%
sns.heatmap(corr_matrix, cmap='coolwarm')
plt.show()

# %%
hotel_data.drop(["Booking_ID","lead_time","repeated_guest","no_of_previous_cancellations", "no_of_previous_bookings_not_canceled"],axis=1,inplace=True)

# %%
hotel_data.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  \
# 0       Meal Plan 1                           0        Room_Type 1
# 1      Not Selected                           0        Room_Type 1
# 2       Meal Plan 1                           0        Room_Type 1
# 3       Meal Plan 1                           0        Room_Type 1
# 4      Not Selected                           0        Room_Type 1
#
#    arrival_year  arrival_month  arrival_date market_segment_type  \
# ...

# %%
hotel_data.drop(["arrival_date","type_of_meal_plan"],axis=1,inplace=True)

# %%
hotel_data[['avg_price_per_room']]= hotel_data[['avg_price_per_room']].astype('int64')

# %%
hotel_data.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#    required_car_parking_space room_type_reserved  arrival_year  arrival_month  \
# 0                           0        Room_Type 1          2017             10
# 1                           0        Room_Type 1          2018             11
# 2                           0        Room_Type 1          2018              2
# 3                           0        Room_Type 1          2018              5
# 4                           0        Room_Type 1          2018              4
#
# ...

# %%
# #data=hotel_data[:-1]
# class_mapping={
#     "Not_Canceled":0,
#     "Canceled":1
# }
# y_encoded = np.zeros(data.shape)
# for label, cls in class_mapping.items():
#     y_encoded[data == label] = cls

# %%
hotel_data['booking_status'] = hotel_data['booking_status'].map({"Not_Canceled":0,"Canceled":1})

# %%
hotel_data
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 36270             3               0                     2                  6
# 36271             2               0                     1                  3
# 36272             2               0                     2                  6
# 36273             2               0                     0                  3
# 36274             2               0                     1                  2
#
# ...

# %%
hotel_data['arrival_month'].value_counts()
# Out:
# 10    5317
# 9     4611
# 8     3813
# 6     3203
# 12    3021
# 11    2980
# 7     2920
# 4     2736
# 5     2598
# 3     2358
# 2     1704
# 1     1014
# Name: arrival_month, dtype: int64

# %%
def one_hot_encoding(data,variable):
    unique_values = data[variable].unique()
    one_hot_dict = {}
    for value in unique_values:
        new_column = f"{variable}_{value}"
        data[new_column] = 0
        one_hot_dict[value] = new_column
    for index, row in data.iterrows():
        value = row[variable]
        new_column = one_hot_dict[value]
        data.at[index, new_column] = 1
#         data = data.drop(variable, axis=1)
    return data

# %%
hotel_data.columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'required_car_parking_space', 'room_type_reserved',
#        'arrival_year', 'arrival_month', 'market_segment_type',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
cat_cols=['room_type_reserved','market_segment_type']

# %%
for i in cat_cols:
    hotel_data=one_hot_encoding(hotel_data,i)
    hotel_data=hotel_data.drop(i,1)

# %%
hotel_data
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 36270             3               0                     2                  6
# 36271             2               0                     1                  3
# 36272             2               0                     2                  6
# 36273             2               0                     0                  3
# 36274             2               0                     1                  2
#
# ...

# %%
hotel_data.columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'required_car_parking_space', 'arrival_year',
#        'arrival_month', 'avg_price_per_room', 'no_of_special_requests',
#        'booking_status', 'room_type_reserved_Room_Type 1',
#        'room_type_reserved_Room_Type 4', 'room_type_reserved_Room_Type 2',
#        'room_type_reserved_Room_Type 6', 'room_type_reserved_Room_Type 5',
#        'room_type_reserved_Room_Type 7', 'room_type_reserved_Room_Type 3',
#        'market_segment_type_Offline', 'market_segment_type_Online',
#        'market_segment_type_Corporate', 'market_segment_type_Aviation',
#        'market_segment_type_Complementary'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

data_scaled = StandardScaler()

# %%
hotel_data1=data_scaled.fit_transform(hotel_data.select_dtypes(include=np.number))
hotel_data1
# Out:
# array([[ 0.29889263, -0.26147045,  0.2174012 , ..., -0.24264534,
#         -0.05880319, -0.10438497],
#        [ 0.29889263, -0.26147045,  1.36599262, ..., -0.24264534,
#         -0.05880319, -0.10438497],
#        [-1.62897546, -0.26147045,  1.36599262, ..., -0.24264534,
#         -0.05880319, -0.10438497],
#        ...,
#        [ 0.29889263, -0.26147045,  1.36599262, ..., -0.24264534,
#         -0.05880319, -0.10438497],
#        [ 0.29889263, -0.26147045, -0.93119021, ..., -0.24264534,
#         -0.05880319, -0.10438497],
#        [ 0.29889263, -0.26147045,  0.2174012 , ..., -0.24264534,
#         -0.05880319, -0.10438497]])

# %%
import math
def find_entropy(data):
    
    entropy=0
    values=hotel_data['booking_status'].unique()
    for value in values:
        frac = hotel_data['booking_status'].value_counts()[value]/len(hotel_data['booking_status'])
        entropy += -frac*math.log(frac,2)
    return entropy

# %%
find_entropy(hotel_data1)
# Out:
# 0.9124929479549404

# %%
def find_best_attribute(data):
    
    total_entropy = find_entropy(data)
    best_info_gain = 0
    best_attr = None
    for attr in data.columns[1:]:
        values = data[attr].unique()
        entropy = 0
        for value in values:
            sub_data1 = data[data[attr] == value]
            fraction = len(sub_data1)/len(data)
            entropy += fraction*find_entropy(sub_data1)
        info_gain = total_entropy - entropy
        if info_gain > best_info_gain:
            best_info_gain = info_gain
            best_attr = attr
    return best_attr

# %%
find_best_attribute(hotel_data)
# Out:
# 'no_of_weekend_nights'

# %%
list1=[]
def information_gain(data,feature):
    list1=[]
    feature_values = data[feature].unique()
    entropy_before_split = find_entropy(data)
    entropy_after_split = 0
    for value in feature_values:
        subset = data[data[feature] == value]
        entropy_after_split += (len(subset) / len(data)) * find_entropy(subset)
        list1.append(entropy_after_split)
    return list1[0]

# %%
information_gain(hotel_data,'no_of_weekend_nights')
# Out:
# 0.25142293631453144

# %%
from sklearn.model_selection import train_test_split
X=hotel_data.drop('booking_status',axis=1)
y=hotel_data['booking_status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
y_train
# Out:
# 32786    1
# 3572     1
# 10149    0
# 12679    0
# 4570     0
#         ..
# 7763     1
# 15377    0
# 17730    1
# 28030    0
# 15725    0
# Name: booking_status, Length: 25392, dtype: int64

# %%
len(y_train)
print('Y Target Size:', len(y_train))
print('X Train Size:', len(X_train))
print('X Test  Size:', len(X_test))
print('Y Target Size:', len(y_test))
# Out:
# Y Target Size: 25392
# X Train Size: 25392
# X Test  Size: 10883
# Y Target Size: 10883

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = clf.predict(X_train)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score

# %%
def evaluate_model(act, pred):
    print("Confusion Matrix \n", confusion_matrix(act, pred))
    print("Accurcay : ", accuracy_score(act, pred))
    print("Recall   : ", recall_score(act, pred))
    print("Precision: ", precision_score(act, pred))

# %%
print("--Train--")
evaluate_model(y_train, y_pred)
# Out:
# --Train--
# Confusion Matrix
#  [[16735   264]
#  [  643  7750]]
# Accurcay :  0.9642800882167611
# Recall   :  0.9233885380674371
# Precision:  0.9670576491140505
